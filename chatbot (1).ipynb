# %%
import google.generativeai as genai

# %%
# Set your API key
API_KEY = "AIzaSyBQB6nwEynPss_s0MemwJjXUlVW7t6aXPc"
genai.configure(api_key=API_KEY)

# List available models
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)

# Initialize the model (Choose one from the list above that supports generateContent)
model = genai.GenerativeModel("gemini-1.5-flash-latest")

def chat_with_gemini(user_input):
    response = model.generate_content(user_input)
    return response.text

if __name__ == "__main__":
    print("Welcome to Gemini Chatbot! Type 'exit' to quit.")
    while True:
        user_input = input("You: ")
        if user_input.lower() == "exit":
            break
        response = chat_with_gemini(user_input)
        print(f"Gemini: {response}")
# Out:
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.5-pro-exp-03-25
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash-preview-04-17
# models/gemini-2.5-flash-preview-05-20
# models/gemini-2.5-flash-preview-04-17-thinking
# models/gemini-2.5-pro-preview-05-06
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-preview-image-generation
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/learnlm-2.0-flash-experimental
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# Welcome to Gemini Chatbot! Type 'exit' to quit.
# You: exit

# %%
import os
import google.generativeai as genai

# 1) Configure your Gemini API key
genai.configure(api_key="AIzaSyBQB6nwEynPss_s0MemwJjXUlVW7t6aXPc")  # ← replace with your real key

# 2) Choose the free-tier model
model = genai.GenerativeModel("gemini-1.5-flash")

def generate_and_display_script():
    # 3) Ask user for a topic
    topic = input("Enter the script topic: ").strip()
    if not topic:
        print("No topic entered. Exiting.")
        return

    # 4) Build a prompt to ask Gemini for a “script”
    prompt = (
        f"Please write a detailed script on the topic: \"{topic}\".\n"
        "Structure it into scenes or sections, include character names/dialogue, and make it coherent as a standalone script."
    )

    # 5) Start a fresh chat (empty history)
    chat = model.start_chat(history=[])

    # 6) Send the prompt and receive the response
    response = chat.send_message(prompt)

    # 7) Extract the generated script text
    script_text = response.text.strip()
    if not script_text:
        print("Gemini returned an empty response. Try again.")
        return

    # 8) Display the script
    print("\n--- Generated Script ---")
    print(script_text)
    print("------------------------")


if __name__ == "__main__":
    generate_and_display_script()
# Out:
# Enter the script topic: code
#
# --- Generated Script ---
# ## Code: A Play in Three Acts
#
# **Characters:**
#
# * **AVA:** A seasoned programmer, mid-30s, sharp and driven.
# * **LEO:** A bright but inexperienced coding student, early 20s, enthusiastic but easily frustrated.
# * **THE VOICE (V.O.):** A disembodied voice, possibly AI, calm and authoritative.
#
#
# **Act I: The Seed of an Idea**
#
# **Scene 1: A dimly lit university computer lab.**
#
# **(Leo hunches over a laptop, frustrated. Ava sits nearby, calmly working on her own project.)**
#
# **LEO:** (Muttering to himself)  It's not working!  The loop won't break.  I've tried everything!  It's like…like the code is mocking me.
#
# **AVA:** (Without looking up)  Trouble with a loop?  Care to explain?
#
# **LEO:**  It's supposed to generate a Fibonacci sequence, but it just keeps going, endlessly printing numbers.  I've checked the syntax a hundred times.
#
# **AVA:**  Let's see. (She looks over his shoulder.)  Ah, I see the problem.  You're missing a termination condition in your `while` loop. You need to specify when it should stop.
#
# **LEO:**  Oh!  Of course!  I completely overlooked that.  Thanks!
#
# **(Leo fixes the code. A small smile creeps onto his face.)**
#
# **AVA:**  Coding is all about attention to detail.  One small mistake can snowball into a huge problem.  Think of it like building a house – every brick counts.
#
# **LEO:**  I guess you're right.  It feels…magical, though.  To be able to create something from nothing, just using lines of code.
#
# **AVA:**  It is magical.  But it's also hard work and relentless problem-solving.  Don't get discouraged.
#
#
# **Act II: The Debugging Nightmare**
#
# **Scene 2: Ava's home office, late at night.**
#
# **(Ava is staring intensely at multiple screens, surrounded by empty coffee cups.  Frustration is etched on her face. The V.O. is heard faintly.)**
#
# **V.O.:**  Line 347.  Syntax error.  Unexpected token.
#
# **AVA:** (Muttering)  No, no, no!  I’ve checked that a thousand times!  This is a critical bug.  The entire system could crash.
#
# **(Ava types furiously, then pauses, running a diagnostic.)**
#
# **V.O.:**  Memory leak detected.  Resource exhaustion imminent.
#
# **AVA:** (Sighs deeply)  This is going to take all night.
#
# **(She continues debugging, muttering code fragments and technical terms.  The tension is palpable.)**
#
# **Scene 3:  Ava's home office, the next morning.**
#
# **(Ava looks relieved.  She leans back in her chair, stretching.)**
#
# **AVA:**  Finally!  The bug is squashed.  A rogue semicolon was the culprit.  Such a tiny thing can cause such chaos.
#
# **(She looks at the clean code on the screen with satisfaction.)**
#
#
# **Act III:  The Legacy of Code**
#
# **Scene 4: A large tech conference.**
#
# **(Leo, now a confident young programmer, approaches Ava's presentation booth.  He looks up to her with admiration.)**
#
# **LEO:**  Ms. Sharma?  I'm Leo.  I was in your introductory programming class a few years ago.  I remember you talking about how code is like building a house.
#
# **AVA:** (Smiling)  Hello, Leo.  It's good to see you.  How's your coding going?
#
# **LEO:**  It's going great!  I'm working on a project that uses the very algorithms we discussed in class.  It's still challenging, but I feel like I've come a long way.  Your teaching made a real difference.
#
# **AVA:** (Proudly)  I'm glad to hear that.  Remember – good code is clear, efficient, and robust.  And always remember to comment your code.
#
# **LEO:** (Laughing)  I learned that the hard way!  Thanks for everything.
#
# **(Leo shakes Ava's hand.  Ava looks at the audience, then back at Leo, a thoughtful expression on her face.)**
#
# **AVA:** (V.O.) Code isn't just about lines of text on a screen.  It's about creativity, problem-solving, and building something that can truly impact the world. It's a legacy, passed on from programmer to programmer, generation to generation.  And that, in itself, is magical.
#
#
# **(The lights fade.)**
# ------------------------
